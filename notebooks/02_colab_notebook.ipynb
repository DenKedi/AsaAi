# %%
# Alle notwendigen Imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

from collections import deque
import numpy as np
import random
import os

import gymnasium as gym

# Reproduzierbarkeit
seed = 1
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)

# Deterministisches Verhalten für CUDA-Operationen
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print("✅ Imports und Konfiguration geladen.")
# Out:
# ✅ Imports und Konfiguration geladen.

# %%
# %load_ext tensorboard
# %xmode Verbose
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Exception reporting mode: Verbose

# %%
#GPU-Nutzung prüfen und einstellen
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
#Hyperparameter
env_name = "CartPole-v1"
gamma = 0.99 #Discount Faktor
learning_rate = 0.00025 #Gewichtsanpassung

#Epsilon Greedy
eps_start = 0.5 #Start: Nur Ausprobieren
eps = eps_start
eps_end = 0.05
eps_decay = 1000 #Absenkung

train_freq = 1
min_replay_size = 1000
batch_size = 64
gamma = 0.99
target_update_freq = 1000
batch_size = 64
buffer_size = 100_000
min_replay_size = 1_000
train_freq = 1

max_episodes = 500 #default
max_steps = 500 #default
train_episodes = max_episodes
decay_factor = (eps_start - eps_end) / train_episodes

# %%
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

# %%
class QNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(QNetwork, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim) #output = die Anzahl aller möglichen Aktionen
        )

    def forward(self, x):
        return self.model(x)

# %%
class ReplayBuffer:
    def __init__(self, capacity): #capacity ist die Länge der dequeue
        self.buffer = deque(maxlen=capacity) #double ended queue

    def push(self, state, action, reward, next_state, done): #siehe http://www.incompleteideas.net/book/ebook/figtmp7.png
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        samples = random.sample(self.buffer, batch_size) #random weil siehe Doku Quellen dazu
        states, actions, rewards, next_states, dones = zip(*samples)
        return (
            torch.tensor(states, dtype=torch.float32, device=device),
            torch.tensor(actions, dtype=torch.int64, device=device).unsqueeze(1), #https://docs.pytorch.org/docs/main/generated/torch.unsqueeze.html
            torch.tensor(rewards, dtype=torch.float32, device=device).unsqueeze(1),
            torch.tensor(next_states, dtype=torch.float32, device=device),
            torch.tensor(dones, dtype=torch.float32, device=device).unsqueeze(1),
        )

    def __len__(self):
        return len(self.buffer)

# %%
def getEpsilonLin():
    global eps
    eps = max(eps - decay_factor, eps_end)
    return eps

# %%
policy_net = QNetwork(state_dim, action_dim).to(device)
target_net = QNetwork(state_dim, action_dim).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)
replay_buffer = ReplayBuffer(buffer_size)
writer = SummaryWriter()

global_step = 0
episode_rewards = []

# %%
for episode in range(max_episodes):
    state, _ = env.reset()
    state = np.array(state, dtype=np.float32)
    total_reward = 0

    for step in range(max_steps):
        epsilon = getEpsilonLin()  #linear pro Step
        global_step += 1

        #Action wählen
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            with torch.no_grad():
                state_tensor = torch.tensor(state, device=device).unsqueeze(0)
                q_values = policy_net(state_tensor)
                action = q_values.argmax(1).item()

        #Schritt im Environment
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_state = np.array(next_state, dtype=np.float32)

        #Reward Clipping derzeit aus, für cartpole nicht nötig
        #clipped_reward = max(min(reward, 1.0), -1.0)
        clipped_reward = reward

        #In Replay Buffer speichern
        replay_buffer.push(state, action, clipped_reward, next_state, done)

        state = next_state
        total_reward += reward

        #Trainingz
        if len(replay_buffer) >= min_replay_size and global_step % train_freq == 0:
            states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)

            with torch.no_grad():
                #Double DQN: Aktion über policy, Q über target
                next_actions = policy_net(next_states).argmax(1, keepdim=True)
                next_q_values = target_net(next_states).gather(1, next_actions)
                target_q = rewards + (1 - dones) * gamma * next_q_values

            current_q = policy_net(states).gather(1, actions)
            loss = nn.SmoothL1Loss()(current_q, target_q)  #Huber

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Target Network Update
        if global_step % target_update_freq == 0:
            target_net.load_state_dict(policy_net.state_dict())

        if done:
            break

    #Logging
    writer.add_scalar("Reward", total_reward, episode)
    writer.add_scalar("Epsilon", epsilon, episode)
    episode_rewards.append(total_reward)

    print(f"Episode {episode} - Total Reward: {total_reward:.2f} - Epsilon: {epsilon:.3f}")

env.close()
writer.close()
#successful_episodes = sum(1 for r in episode_rewards if r > 450)
#perfect_episodes = sum(1 for r in episode_rewards if r == 500)
#print(f"Episoden mit Reward >450: {successful_episodes}")
#print(f"Perfekte Episoden: {perfect_episodes}")
# Out:
# Episode 0 - Total Reward: 13.00 - Epsilon: 0.488
# Episode 1 - Total Reward: 15.00 - Epsilon: 0.475
# Episode 2 - Total Reward: 14.00 - Epsilon: 0.462
# Episode 3 - Total Reward: 14.00 - Epsilon: 0.450
# Episode 4 - Total Reward: 13.00 - Epsilon: 0.438
# Episode 5 - Total Reward: 11.00 - Epsilon: 0.428
# Episode 6 - Total Reward: 11.00 - Epsilon: 0.418
# Episode 7 - Total Reward: 9.00 - Epsilon: 0.410
# Episode 8 - Total Reward: 9.00 - Epsilon: 0.402
# Episode 9 - Total Reward: 11.00 - Epsilon: 0.392
# Episode 10 - Total Reward: 19.00 - Epsilon: 0.375
# Episode 11 - Total Reward: 12.00 - Epsilon: 0.364
# Episode 12 - Total Reward: 14.00 - Epsilon: 0.351
# Episode 13 - Total Reward: 14.00 - Epsilon: 0.339
# Episode 14 - Total Reward: 10.00 - Epsilon: 0.330
# Episode 15 - Total Reward: 12.00 - Epsilon: 0.319
# Episode 16 - Total Reward: 10.00 - Epsilon: 0.310
# Episode 17 - Total Reward: 10.00 - Epsilon: 0.301
# Episode 18 - Total Reward: 10.00 - Epsilon: 0.292
# Episode 19 - Total Reward: 9.00 - Epsilon: 0.284
# Episode 20 - Total Reward: 8.00 - Epsilon: 0.277
# Episode 21 - Total Reward: 13.00 - Epsilon: 0.265
# Episode 22 - Total Reward: 14.00 - Epsilon: 0.252
# Episode 23 - Total Reward: 15.00 - Epsilon: 0.239
# Episode 24 - Total Reward: 11.00 - Epsilon: 0.229
# Episode 25 - Total Reward: 11.00 - Epsilon: 0.219
# Episode 26 - Total Reward: 9.00 - Epsilon: 0.211
# Episode 27 - Total Reward: 10.00 - Epsilon: 0.202
# Episode 28 - Total Reward: 14.00 - Epsilon: 0.189
# Episode 29 - Total Reward: 10.00 - Epsilon: 0.180
# Episode 30 - Total Reward: 10.00 - Epsilon: 0.171
# Episode 31 - Total Reward: 10.00 - Epsilon: 0.162
# Episode 32 - Total Reward: 12.00 - Epsilon: 0.152
# Episode 33 - Total Reward: 9.00 - Epsilon: 0.144
# Episode 34 - Total Reward: 9.00 - Epsilon: 0.135
# Episode 35 - Total Reward: 9.00 - Epsilon: 0.127
# Episode 36 - Total Reward: 8.00 - Epsilon: 0.120
# Episode 37 - Total Reward: 10.00 - Epsilon: 0.111
# Episode 38 - Total Reward: 11.00 - Epsilon: 0.101
# Episode 39 - Total Reward: 9.00 - Epsilon: 0.093
# Episode 40 - Total Reward: 9.00 - Epsilon: 0.085
# Episode 41 - Total Reward: 12.00 - Epsilon: 0.074
# Episode 42 - Total Reward: 9.00 - Epsilon: 0.066
# Episode 43 - Total Reward: 9.00 - Epsilon: 0.058
# Episode 44 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 45 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 46 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 47 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 48 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 49 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 50 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 51 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 52 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 53 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 54 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 55 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 56 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 57 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 58 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 59 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 60 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 61 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 62 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 63 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 64 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 65 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 66 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 67 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 68 - Total Reward: 13.00 - Epsilon: 0.050
# Episode 69 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 70 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 71 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 72 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 73 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 74 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 75 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 76 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 77 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 78 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 79 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 80 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 81 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 82 - Total Reward: 13.00 - Epsilon: 0.050
# Episode 83 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 84 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 85 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 86 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 87 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 88 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 89 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 90 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 91 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 92 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 93 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 94 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 95 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 96 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 97 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 98 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 99 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 100 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 101 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 102 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 103 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 104 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 105 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 106 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 107 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 108 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 109 - Total Reward: 19.00 - Epsilon: 0.050
# Episode 110 - Total Reward: 14.00 - Epsilon: 0.050
# Episode 111 - Total Reward: 15.00 - Epsilon: 0.050
# Episode 112 - Total Reward: 14.00 - Epsilon: 0.050
# Episode 113 - Total Reward: 17.00 - Epsilon: 0.050
# Episode 114 - Total Reward: 13.00 - Epsilon: 0.050
# Episode 115 - Total Reward: 16.00 - Epsilon: 0.050
# Episode 116 - Total Reward: 15.00 - Epsilon: 0.050
# Episode 117 - Total Reward: 17.00 - Epsilon: 0.050
# Episode 118 - Total Reward: 22.00 - Epsilon: 0.050
# Episode 119 - Total Reward: 27.00 - Epsilon: 0.050
# Episode 120 - Total Reward: 56.00 - Epsilon: 0.050
# Episode 121 - Total Reward: 20.00 - Epsilon: 0.050
# Episode 122 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 123 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 124 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 125 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 126 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 127 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 128 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 129 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 130 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 131 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 132 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 133 - Total Reward: 13.00 - Epsilon: 0.050
# Episode 134 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 135 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 136 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 137 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 138 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 139 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 140 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 141 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 142 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 143 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 144 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 145 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 146 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 147 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 148 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 149 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 150 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 151 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 152 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 153 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 154 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 155 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 156 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 157 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 158 - Total Reward: 15.00 - Epsilon: 0.050
# Episode 159 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 160 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 161 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 162 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 163 - Total Reward: 17.00 - Epsilon: 0.050
# Episode 164 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 165 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 166 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 167 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 168 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 169 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 170 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 171 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 172 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 173 - Total Reward: 19.00 - Epsilon: 0.050
# Episode 174 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 175 - Total Reward: 13.00 - Epsilon: 0.050
# Episode 176 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 177 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 178 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 179 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 180 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 181 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 182 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 183 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 184 - Total Reward: 58.00 - Epsilon: 0.050
# Episode 185 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 186 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 187 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 188 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 189 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 190 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 191 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 192 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 193 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 194 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 195 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 196 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 197 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 198 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 199 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 200 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 201 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 202 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 203 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 204 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 205 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 206 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 207 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 208 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 209 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 210 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 211 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 212 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 213 - Total Reward: 18.00 - Epsilon: 0.050
# Episode 214 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 215 - Total Reward: 17.00 - Epsilon: 0.050
# Episode 216 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 217 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 218 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 219 - Total Reward: 15.00 - Epsilon: 0.050
# Episode 220 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 221 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 222 - Total Reward: 24.00 - Epsilon: 0.050
# Episode 223 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 224 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 225 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 226 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 227 - Total Reward: 33.00 - Epsilon: 0.050
# Episode 228 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 229 - Total Reward: 39.00 - Epsilon: 0.050
# Episode 230 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 231 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 232 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 233 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 234 - Total Reward: 33.00 - Epsilon: 0.050
# Episode 235 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 236 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 237 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 238 - Total Reward: 29.00 - Epsilon: 0.050
# Episode 239 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 240 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 241 - Total Reward: 27.00 - Epsilon: 0.050
# Episode 242 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 243 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 244 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 245 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 246 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 247 - Total Reward: 22.00 - Epsilon: 0.050
# Episode 248 - Total Reward: 54.00 - Epsilon: 0.050
# Episode 249 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 250 - Total Reward: 60.00 - Epsilon: 0.050
# Episode 251 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 252 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 253 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 254 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 255 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 256 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 257 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 258 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 259 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 260 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 261 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 262 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 263 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 264 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 265 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 266 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 267 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 268 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 269 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 270 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 271 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 272 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 273 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 274 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 275 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 276 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 277 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 278 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 279 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 280 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 281 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 282 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 283 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 284 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 285 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 286 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 287 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 288 - Total Reward: 42.00 - Epsilon: 0.050
# Episode 289 - Total Reward: 20.00 - Epsilon: 0.050
# Episode 290 - Total Reward: 16.00 - Epsilon: 0.050
# Episode 291 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 292 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 293 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 294 - Total Reward: 13.00 - Epsilon: 0.050
# Episode 295 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 296 - Total Reward: 10.00 - Epsilon: 0.050
# Episode 297 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 298 - Total Reward: 64.00 - Epsilon: 0.050
# Episode 299 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 300 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 301 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 302 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 303 - Total Reward: 16.00 - Epsilon: 0.050
# Episode 304 - Total Reward: 27.00 - Epsilon: 0.050
# Episode 305 - Total Reward: 15.00 - Epsilon: 0.050
# Episode 306 - Total Reward: 17.00 - Epsilon: 0.050
# Episode 307 - Total Reward: 18.00 - Epsilon: 0.050
# Episode 308 - Total Reward: 72.00 - Epsilon: 0.050
# Episode 309 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 310 - Total Reward: 48.00 - Epsilon: 0.050
# Episode 311 - Total Reward: 8.00 - Epsilon: 0.050
# Episode 312 - Total Reward: 28.00 - Epsilon: 0.050
# Episode 313 - Total Reward: 34.00 - Epsilon: 0.050
# Episode 314 - Total Reward: 48.00 - Epsilon: 0.050
# Episode 315 - Total Reward: 9.00 - Epsilon: 0.050
# Episode 316 - Total Reward: 52.00 - Epsilon: 0.050
# Episode 317 - Total Reward: 21.00 - Epsilon: 0.050
# Episode 318 - Total Reward: 15.00 - Epsilon: 0.050
# Episode 319 - Total Reward: 25.00 - Epsilon: 0.050
# Episode 320 - Total Reward: 11.00 - Epsilon: 0.050
# Episode 321 - Total Reward: 21.00 - Epsilon: 0.050
# Episode 322 - Total Reward: 68.00 - Epsilon: 0.050
# Episode 323 - Total Reward: 67.00 - Epsilon: 0.050
# Episode 324 - Total Reward: 88.00 - Epsilon: 0.050
# Episode 325 - Total Reward: 12.00 - Epsilon: 0.050
# Episode 326 - Total Reward: 33.00 - Epsilon: 0.050
# Episode 327 - Total Reward: 26.00 - Epsilon: 0.050
# Episode 328 - Total Reward: 73.00 - Epsilon: 0.050
# Episode 329 - Total Reward: 57.00 - Epsilon: 0.050
# Episode 330 - Total Reward: 121.00 - Epsilon: 0.050
# Episode 331 - Total Reward: 57.00 - Epsilon: 0.050
# Episode 332 - Total Reward: 45.00 - Epsilon: 0.050
# Episode 333 - Total Reward: 65.00 - Epsilon: 0.050
# Episode 334 - Total Reward: 382.00 - Epsilon: 0.050
# Episode 335 - Total Reward: 148.00 - Epsilon: 0.050
# Episode 336 - Total Reward: 128.00 - Epsilon: 0.050
# Episode 337 - Total Reward: 212.00 - Epsilon: 0.050
# Episode 338 - Total Reward: 184.00 - Epsilon: 0.050
# Episode 339 - Total Reward: 123.00 - Epsilon: 0.050
# Episode 340 - Total Reward: 84.00 - Epsilon: 0.050
# Episode 341 - Total Reward: 83.00 - Epsilon: 0.050
# Episode 342 - Total Reward: 110.00 - Epsilon: 0.050
# Episode 343 - Total Reward: 159.00 - Epsilon: 0.050
# Episode 344 - Total Reward: 155.00 - Epsilon: 0.050
# Episode 345 - Total Reward: 123.00 - Epsilon: 0.050
# Episode 346 - Total Reward: 122.00 - Epsilon: 0.050
# Episode 347 - Total Reward: 77.00 - Epsilon: 0.050
# Episode 348 - Total Reward: 161.00 - Epsilon: 0.050
# Episode 349 - Total Reward: 206.00 - Epsilon: 0.050
# Episode 350 - Total Reward: 137.00 - Epsilon: 0.050
# Episode 351 - Total Reward: 145.00 - Epsilon: 0.050
# Episode 352 - Total Reward: 243.00 - Epsilon: 0.050
# Episode 353 - Total Reward: 182.00 - Epsilon: 0.050
# Episode 354 - Total Reward: 131.00 - Epsilon: 0.050
# Episode 355 - Total Reward: 227.00 - Epsilon: 0.050
# Episode 356 - Total Reward: 147.00 - Epsilon: 0.050
# Episode 357 - Total Reward: 184.00 - Epsilon: 0.050
# Episode 358 - Total Reward: 171.00 - Epsilon: 0.050
# Episode 359 - Total Reward: 162.00 - Epsilon: 0.050
# Episode 360 - Total Reward: 170.00 - Epsilon: 0.050
# Episode 361 - Total Reward: 176.00 - Epsilon: 0.050
# Episode 362 - Total Reward: 136.00 - Epsilon: 0.050
# Episode 363 - Total Reward: 144.00 - Epsilon: 0.050
# Episode 364 - Total Reward: 157.00 - Epsilon: 0.050
# Episode 365 - Total Reward: 186.00 - Epsilon: 0.050
# Episode 366 - Total Reward: 140.00 - Epsilon: 0.050
# Episode 367 - Total Reward: 195.00 - Epsilon: 0.050
# Episode 368 - Total Reward: 154.00 - Epsilon: 0.050
# Episode 369 - Total Reward: 215.00 - Epsilon: 0.050
# Episode 370 - Total Reward: 234.00 - Epsilon: 0.050
# Episode 371 - Total Reward: 253.00 - Epsilon: 0.050
# Episode 372 - Total Reward: 244.00 - Epsilon: 0.050
# Episode 373 - Total Reward: 247.00 - Epsilon: 0.050
# Episode 374 - Total Reward: 229.00 - Epsilon: 0.050
# Episode 375 - Total Reward: 418.00 - Epsilon: 0.050
# Episode 376 - Total Reward: 237.00 - Epsilon: 0.050
# Episode 377 - Total Reward: 221.00 - Epsilon: 0.050
# Episode 378 - Total Reward: 167.00 - Epsilon: 0.050
# Episode 379 - Total Reward: 236.00 - Epsilon: 0.050
# Episode 380 - Total Reward: 252.00 - Epsilon: 0.050
# Episode 381 - Total Reward: 235.00 - Epsilon: 0.050
# Episode 382 - Total Reward: 241.00 - Epsilon: 0.050
# Episode 383 - Total Reward: 155.00 - Epsilon: 0.050
# Episode 384 - Total Reward: 262.00 - Epsilon: 0.050
# Episode 385 - Total Reward: 216.00 - Epsilon: 0.050
# Episode 386 - Total Reward: 165.00 - Epsilon: 0.050
# Episode 387 - Total Reward: 267.00 - Epsilon: 0.050
# Episode 388 - Total Reward: 233.00 - Epsilon: 0.050
# Episode 389 - Total Reward: 313.00 - Epsilon: 0.050
# Episode 390 - Total Reward: 177.00 - Epsilon: 0.050
# Episode 391 - Total Reward: 304.00 - Epsilon: 0.050
# Episode 392 - Total Reward: 252.00 - Epsilon: 0.050
# Episode 393 - Total Reward: 303.00 - Epsilon: 0.050
# Episode 394 - Total Reward: 181.00 - Epsilon: 0.050
# Episode 395 - Total Reward: 21.00 - Epsilon: 0.050
# Episode 396 - Total Reward: 243.00 - Epsilon: 0.050
# Episode 397 - Total Reward: 179.00 - Epsilon: 0.050
# Episode 398 - Total Reward: 208.00 - Epsilon: 0.050
# Episode 399 - Total Reward: 207.00 - Epsilon: 0.050
# Episode 400 - Total Reward: 219.00 - Epsilon: 0.050
# Episode 401 - Total Reward: 231.00 - Epsilon: 0.050
# Episode 402 - Total Reward: 221.00 - Epsilon: 0.050
# Episode 403 - Total Reward: 200.00 - Epsilon: 0.050
# Episode 404 - Total Reward: 198.00 - Epsilon: 0.050
# Episode 405 - Total Reward: 275.00 - Epsilon: 0.050
# Episode 406 - Total Reward: 254.00 - Epsilon: 0.050
# Episode 407 - Total Reward: 221.00 - Epsilon: 0.050
# Episode 408 - Total Reward: 212.00 - Epsilon: 0.050
# Episode 409 - Total Reward: 200.00 - Epsilon: 0.050
# Episode 410 - Total Reward: 246.00 - Epsilon: 0.050
# Episode 411 - Total Reward: 234.00 - Epsilon: 0.050
# Episode 412 - Total Reward: 189.00 - Epsilon: 0.050
# Episode 413 - Total Reward: 184.00 - Epsilon: 0.050
# Episode 414 - Total Reward: 192.00 - Epsilon: 0.050
# Episode 415 - Total Reward: 174.00 - Epsilon: 0.050
# Episode 416 - Total Reward: 165.00 - Epsilon: 0.050
# Episode 417 - Total Reward: 149.00 - Epsilon: 0.050
# Episode 418 - Total Reward: 183.00 - Epsilon: 0.050
# Episode 419 - Total Reward: 201.00 - Epsilon: 0.050
# Episode 420 - Total Reward: 199.00 - Epsilon: 0.050
# Episode 421 - Total Reward: 159.00 - Epsilon: 0.050
# Episode 422 - Total Reward: 164.00 - Epsilon: 0.050
# Episode 423 - Total Reward: 210.00 - Epsilon: 0.050
# Episode 424 - Total Reward: 180.00 - Epsilon: 0.050
# Episode 425 - Total Reward: 181.00 - Epsilon: 0.050
# Episode 426 - Total Reward: 174.00 - Epsilon: 0.050
# Episode 427 - Total Reward: 211.00 - Epsilon: 0.050
# Episode 428 - Total Reward: 181.00 - Epsilon: 0.050
# Episode 429 - Total Reward: 193.00 - Epsilon: 0.050
# Episode 430 - Total Reward: 197.00 - Epsilon: 0.050
# Episode 431 - Total Reward: 215.00 - Epsilon: 0.050
# Episode 432 - Total Reward: 188.00 - Epsilon: 0.050
# Episode 433 - Total Reward: 162.00 - Epsilon: 0.050
# Episode 434 - Total Reward: 177.00 - Epsilon: 0.050
# Episode 435 - Total Reward: 174.00 - Epsilon: 0.050
# Episode 436 - Total Reward: 198.00 - Epsilon: 0.050
# Episode 437 - Total Reward: 177.00 - Epsilon: 0.050
# Episode 438 - Total Reward: 181.00 - Epsilon: 0.050
# Episode 439 - Total Reward: 161.00 - Epsilon: 0.050
# Episode 440 - Total Reward: 173.00 - Epsilon: 0.050
# Episode 441 - Total Reward: 189.00 - Epsilon: 0.050
# Episode 442 - Total Reward: 193.00 - Epsilon: 0.050
# Episode 443 - Total Reward: 160.00 - Epsilon: 0.050
# Episode 444 - Total Reward: 163.00 - Epsilon: 0.050
# Episode 445 - Total Reward: 173.00 - Epsilon: 0.050
# Episode 446 - Total Reward: 164.00 - Epsilon: 0.050
# Episode 447 - Total Reward: 173.00 - Epsilon: 0.050
# Episode 448 - Total Reward: 112.00 - Epsilon: 0.050
# Episode 449 - Total Reward: 146.00 - Epsilon: 0.050
# Episode 450 - Total Reward: 119.00 - Epsilon: 0.050
# Episode 451 - Total Reward: 164.00 - Epsilon: 0.050
# Episode 452 - Total Reward: 161.00 - Epsilon: 0.050
# Episode 453 - Total Reward: 166.00 - Epsilon: 0.050
# Episode 454 - Total Reward: 170.00 - Epsilon: 0.050
# Episode 455 - Total Reward: 159.00 - Epsilon: 0.050
# Episode 456 - Total Reward: 213.00 - Epsilon: 0.050
# Episode 457 - Total Reward: 152.00 - Epsilon: 0.050
# Episode 458 - Total Reward: 206.00 - Epsilon: 0.050
# Episode 459 - Total Reward: 177.00 - Epsilon: 0.050
# Episode 460 - Total Reward: 197.00 - Epsilon: 0.050
# Episode 461 - Total Reward: 231.00 - Epsilon: 0.050
# Episode 462 - Total Reward: 199.00 - Epsilon: 0.050
# Episode 463 - Total Reward: 270.00 - Epsilon: 0.050
# Episode 464 - Total Reward: 153.00 - Epsilon: 0.050
# Episode 465 - Total Reward: 188.00 - Epsilon: 0.050
# Episode 466 - Total Reward: 191.00 - Epsilon: 0.050
# Episode 467 - Total Reward: 188.00 - Epsilon: 0.050
# Episode 468 - Total Reward: 122.00 - Epsilon: 0.050
# Episode 469 - Total Reward: 201.00 - Epsilon: 0.050
# Episode 470 - Total Reward: 207.00 - Epsilon: 0.050
# Episode 471 - Total Reward: 197.00 - Epsilon: 0.050
# Episode 472 - Total Reward: 157.00 - Epsilon: 0.050
# Episode 473 - Total Reward: 177.00 - Epsilon: 0.050
# Episode 474 - Total Reward: 207.00 - Epsilon: 0.050
# Episode 475 - Total Reward: 172.00 - Epsilon: 0.050
# Episode 476 - Total Reward: 192.00 - Epsilon: 0.050
# Episode 477 - Total Reward: 121.00 - Epsilon: 0.050
# Episode 478 - Total Reward: 239.00 - Epsilon: 0.050
# Episode 479 - Total Reward: 183.00 - Epsilon: 0.050
# Episode 480 - Total Reward: 65.00 - Epsilon: 0.050
# Episode 481 - Total Reward: 179.00 - Epsilon: 0.050
# Episode 482 - Total Reward: 178.00 - Epsilon: 0.050
# Episode 483 - Total Reward: 204.00 - Epsilon: 0.050
# Episode 484 - Total Reward: 164.00 - Epsilon: 0.050
# Episode 485 - Total Reward: 119.00 - Epsilon: 0.050
# Episode 486 - Total Reward: 150.00 - Epsilon: 0.050
# Episode 487 - Total Reward: 116.00 - Epsilon: 0.050
# Episode 488 - Total Reward: 362.00 - Epsilon: 0.050
# Episode 489 - Total Reward: 185.00 - Epsilon: 0.050
# Episode 490 - Total Reward: 122.00 - Epsilon: 0.050
# Episode 491 - Total Reward: 134.00 - Epsilon: 0.050
# Episode 492 - Total Reward: 103.00 - Epsilon: 0.050
# Episode 493 - Total Reward: 148.00 - Epsilon: 0.050
# Episode 494 - Total Reward: 153.00 - Epsilon: 0.050
# Episode 495 - Total Reward: 148.00 - Epsilon: 0.050
# Episode 496 - Total Reward: 187.00 - Epsilon: 0.050
# Episode 497 - Total Reward: 154.00 - Epsilon: 0.050
# Episode 498 - Total Reward: 114.00 - Epsilon: 0.050
# Episode 499 - Total Reward: 141.00 - Epsilon: 0.050
